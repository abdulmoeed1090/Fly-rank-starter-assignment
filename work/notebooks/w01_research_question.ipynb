# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdulmoeed1090/Fly-rank-starter-assignment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# ## My Lane
#
# I selected the **Refresh / Content Opportunity Scoring** lane.
#
# ### Why?
#
# The goal of this project is to identify content pages that are most likely to benefit from being refreshed. Instead of manually reviewing thousands of pages, I want to use data to rank pages based on their opportunity for improvement.
#
# This lane interests me because search performance changes over time. Older pages with declining impressions, clicks, or engagement may need updates, while newer pages performing well may not require any action.
#
# A machine learning model can help prioritize which pages should be reviewed first so that editors spend their time where it has the greatest impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


# no code required here

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## Research Question
#
# ### Search Question
#
# Which content pages should be refreshed first to improve search performance and user engagement?
#
# ### Unit of Analysis
#
# Each row in the dataset represents one content page.
#
# ### Decision
#
# The decision is which pages should be prioritized for refreshing.
#
# ### Who Takes the Action?
#
# The content or SEO team reviews the highest-priority pages and updates their content, titles, metadata, keywords, or structure.
#
# ### Cost of a Wrong Recommendation
#
# If an outdated page is not selected for refresh, the company may lose search traffic and user engagement.
#
# If a well-performing page is unnecessarily selected, time and editorial resources are wasted.
#
# ### Why Machine Learning?
#
# The dataset contains many performance indicators such as impressions, clicks, CTR, engagement rate, freshness, and content age. Since manually reviewing thousands of pages is difficult, machine learning can combine these signals to rank pages that are most likely to benefit from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# no code required here

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
# ## Quick Look at the Data
#
# The starter dataset contains thousands of content pages collected from multiple clients.
#
# These pages include information about search performance, engagement, freshness, traffic, and content characteristics.
#
# The statistics below show that the dataset is large enough and contains sufficient variation to support a content opportunity scoring project.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/abdulmoeed1090/Fly-rank-starter-assignment/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)
df.head()

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Clients:", df["client_id"].nunique())

print("\nAverage Search Volume:")
print(round(df["search_volume"].mean(), 2))

print("\nAverage CTR:")
print(round(df["ctr"].mean(), 4))

print("\nAverage Content Age (in days):")
print(round(df["content_age_days"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
# Clients: 32
#
# Average Search Volume:
# 158.88
#
# Average CTR:
# 0.5107
#
# Average Content Age (in days):
# 256.17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ## Careful Words
#
# This project is intended to provide decision support rather than certainty.
#
# The model can identify pages that appear to be good candidates for refreshing based on historical search and engagement signals.
#
# However, it cannot prove that refreshing a page will increase traffic or rankings. Search performance is also affected by external factors such as algorithm updates, competition, seasonality, and user behavior.
#
# The model should therefore be used as a ranking tool to help editors prioritize their work instead of replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code required for this section

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
#
#
# ## -------MY SELF CHECK----------
# ## Self Check
#
# - ✅ I selected one official project lane.
# - ✅ I explained why I chose this lane.
# - ✅ I defined the research question.
# - ✅ I identified the decision and the action.
# - ✅ I explained the cost of a wrong recommendation.
# - ✅ I showed real statistics from the starter dataset.
# - ✅ My notebook runs from top to bottom without errors.
# - ✅ I used careful language and avoided unsupported claims.

# %%
##visualization for easeness of reader (mentor)
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df["content_age_days"].hist(bins=30)

plt.title("Distribution of Content Age")
plt.xlabel("Content Age (Days)")
plt.ylabel("Number of Pages")

plt.show()
